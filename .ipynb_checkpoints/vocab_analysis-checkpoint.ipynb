# %%
from common import Common
import _pickle as pickle
import collections
import re
import matplotlib.pyplot as plt
import operator
# %matplotlib inline

# %%
def dataset(name):
    with open("{}.dict.c2s".format(name), "rb") as file:
        subtoken_to_count = pickle.load(file)
        node_to_count = pickle.load(file)
        target_to_count = pickle.load(file)
        max_contexts = pickle.load(file)
        num_training_examples = pickle.load(file)
        print("Dictionaries loaded.")
        return target_to_count
# Out:
# Dictionaries loaded.

# %%
dataset("data/java-small-bpe-full/java-small-bpe-full")
target_to_count
# Out:
# {'get': 114093,
#  's': 60893,
#  'test': 44064,
#  'ed': 32716,
#  'set': 30660,
#  'e': 27904,
#  'is': 27551,
#  'S': 27018,
#  'd': 24090,
#  'f': 21918,
#  'In': 20169,
#  'F': 20095,
#  'r': 19950,
#  'er': 18973,
#  'es': 18834,
#  'it': 18729,
#  'M': 18188,
#  'create': 17656,
#  'C': 17593,
#  'y': 17349,
#  'D': 17151,
#  'Name': 16901,
#  'p': 16463,
#  'ing': 16463,
#  'c': 16216,
#  'N': 15745,
#  'un': 14891,
#  'h': 14202,
#  'R': 14165,
#  'le': 13970,
#  'P': 13915,
#  'T': 13871,
#  'oo': 13743,
#  'B': 12905,
#  't': 12687,
#  'L': 12179,
#  'To': 11952,
#  'o': 11873,
#  'ate': 11387,
#  'en': 11365,
#  'able': 11225,
#  'ar': 11053,
#  'up': 10996,
#  'in': 10885,
#  'l': 10610,
#  'With': 10609,
#  'al': 10565,
#  'Type': 10505,
#  'Re': 10266,
#  'ation': 10223,
#  'String': 10109,
#  'add': 9967,
#  'se': 9959,
#  'on': 9758,
#  'An': 9623,
#  'A': 9540,
#  'et': 9500,
#  'Ex': 9186,
#  'or': 9101,
#  'Ch': 8917,
#  'to': 8862,
#  'Class': 8786,
#  'I': 8711,
#  'm': 8380,
#  'ent': 8327,
#  'b': 8281,
#  'ic': 8274,
#  'i': 8185,
#  'vis': 8148,
#  'el': 8144,
#  'H': 8072,
#  'O': 7924,
#  'k': 7775,
#  'Id': 7507,
#  'Se': 7504,
#  'ment': 7459,
#  'do': 7443,
#  're': 7439,
#  'cess': 7426,
#  'File': 7319,
#  'Value': 7264,
#  'at': 7229,
#  'g': 7217,
#  'E': 7192,
#  'V': 7140,
#  'ist': 7130,
#  'res': 7104,
#  'a': 7077,
#  'ter': 6936,
#  'For': 6934,
#  'W': 6921,
#  'Element': 6821,
#  'De': 6677,
#  'En': 6648,
#  'ion': 6590,
#  'n': 6496,
#  'ild': 6320,
#  'de': 6267,
#  'Pro': 6222,
#  'date': 6219,
#  'Method': 6122,
#  'u': 6019,
#  'lo': 6012,
#  'form': 5972,
#  'ol': 5864,
#  'ex': 5778,
#  'has': 5772,
#  'ot': 5760,
#  'Con': 5709,
#  'v': 5707,
#  'By': 5706,
#  'ad': 5666,
#  'pro': 5644,
#  'ers': 5616,
#  'Set': 5614,
#  'U': 5588,
#  'J': 5580,
#  'and': 5531,
#  'St': 5516,
#  'ut': 5514,
#  'rom': 5356,
#  'ow': 5269,
#  'lect': 5229,
#  'app': 5221,
#  'st': 5212,
#  'comp': 5144,
#  'il': 5142,
#  'bu': 5086,
#  'Text': 5033,
#  'action': 5019,
#  'ch': 4957,
#  'cl': 4948,
#  'read': 4912,
#  'ang': 4906,
#  'Test': 4868,
#  'State': 4838,
#  'Un': 4811,
#  'ecut': 4776,
#  'con': 4775,
#  'Path': 4702,
#  'On': 4702,
#  'ly': 4639,
#  'find': 4578,
#  've': 4562,
#  'Mod': 4543,
#  'Up': 4471,
#  'x': 4437,
#  'Par': 4364,
#  'Comp': 4350,
#  'est': 4328,
#  'are': 4267,
#  'om': 4232,
#  'lic': 4227,
#  'Code': 4194,
#  'Action': 4165,
#  'ption': 4131,
#  'write': 4080,
#  'Component': 4078,
#  'ive': 4015,
#  'par': 3989,
#  'ro': 3987,
#  'Data': 3981,
#  'em': 3966,
#  'ition': 3965,
#  'Field': 3938,
#  'Default': 3929,
#  'Key': 3921,
#  'ac': 3869,
#  'ure': 3841,
#  'check': 3813,
#  'an': 3783,
#  'Sh': 3738,
#  'Per': 3737,
#  'Pre': 3713,
#  'end': 3711,
#  'ort': 3709,
#  'w': 3675,
#  'let': 3675,
#  'ag': 3648,
#  'Not': 3643,
#  'act': 3620,
#  'us': 3614,
#  'List': 3588,
#  'ange': 3569,
#  'ig': 3563,
#  'id': 3541,
#  'ain': 3521,
#  'Dis': 3500,
#  'ated': 3495,
#  'Val': 3489,
#  'method': 3480,
#  'Or': 3475,
#  'ator': 3456,
#  'Expression': 3442,
#  'as': 3357,
#  'ri': 3350,
#  'reg': 3341,
#  'Ro': 3322,
#  'ver': 3320,
#  'All': 3319,
#  'Property': 3312,
#  'ust': 3283,
#  'equals': 3281,
#  'Context': 3281,
#  'ap': 3273,
#  'ial': 3253,
#  'Descri': 3253,
#  'ind': 3229,
#  'mp': 3199,
#  'ur': 3187,
#  'remove': 3152,
#  'atch': 3146,
#  'Content': 3114,
#  'Trans': 3105,
#  'Child': 3095,
#  'Res': 3073,
#  'um': 3069,
#  'am': 3061,
#  'Th': 3052,
#  'ir': 3040,
#  'for': 3026,
#  'Lin': 3023,
#  'cept': 3014,
#  'Inter': 2982,
#  'ory': 2979,
#  'ace': 2964,
#  'ail': 2964,
#  'pl': 2944,
#  'Fi': 2941,
#  'port': 2934,
#  'sh': 2899,
#  'Error': 2890,
#  'Of': 2872,
#  'Add': 2870,
#  'init': 2863,
#  'ule': 2863,
#  'fer': 2841,
#  'po': 2840,
#  'can': 2839,
#  'At': 2826,
#  'im': 2812,
#  'ize': 2795,
#  'Index': 2793,
#  'Column': 2788,
#  'co': 2742,
#  'ck': 2715,
#  'Instance': 2687,
#  'Project': 2681,
#  'Object': 2672,
#  'G': 2664,
#  'Source': 2648,
#  'As': 2628,
#  'ary': 2615,
#  'Parameter': 2605,
#  'ces': 2601,
#  'Message': 2586,
#  'Sub': 2580,
#  'ke': 2574,
#  'Param': 2566,
#  'ne': 2560,
#  'ard': 2542,
#  'Size': 2536,
#  'ul': 2534,
#  'not': 2529,
#  'vert': 2526,
#  'art': 2516,
#  'Lo': 2507,
#  'mpty': 2490,
#  'ack': 2473,
#  'vo': 2460,
#  'load': 2457,
#  'tr': 2449,
#  'X': 2449,
#  'ity': 2444,
#  'os': 2440,
#  'valid': 2420,
#  'ip': 2412,
#  'pe': 2402,
#  'Bean': 2391,
#  'out': 2390,
#  'if': 2374,
#  'Cre': 2351,
#  'assert': 2351,
#  'Be': 2346,
#  'ache': 2331,
#  'Reference': 2284,
#  'Query': 2282,
#  'all': 2268,
#  'Time': 2267,
#  'Count': 2261,
#  'ult': 2239,
#  'ting': 2233,
#  'sed': 2224,
#  'dis': 2218,
#  'play': 2216,
#  'Attribute': 2216,
#  'Map': 2213,
#  'op': 2205,
#  'Request': 2200,
#  'Arg': 2178,
#  'z': 2174,
#  'ab': 2162,
#  'ce': 2158,
#  'ign': 2153,
#  'qu': 2123,
#  'ore': 2122,
#  'own': 2120,
#  'ast': 2117,
#  'Table': 2106,
#  'Null': 2104,
#  'Result': 2103,
#  'be': 2096,
#  'ies': 2087,
#  'Cont': 2084,
#  'ari': 2073,
#  'Node': 2072,
#  'start': 2068,
#  'Editor': 2064,
#  'Factory': 2054,
#  'ame': 2052,
#  'nal': 2050,
#  'ib': 2044,
#  'der': 2043,
#  'Array': 2037,
#  'Call': 2008,
#  'Exception': 2005,
#  'ames': 2003,
#  'Pan': 1984,
#  'Listener': 1962,
#  'Filter': 1962,
#  'ializ': 1955,
#  'af': 1951,
#  'Ser': 1951,
#  'Entity': 1950,
#  'per': 1946,
#  'Get': 1943,
#  'new': 1942,
#  'Properties': 1935,
#  'ject': 1924,
#  'av': 1921,
#  'Pl': 1918,
#  'arget': 1918,
#  'ight': 1916,
#  'ase': 1891,
#  'irect': 1885,
#  'pre': 1881,
#  'notation': 1865,
#  'lock': 1862,
#  'Writ': 1854,
#  'fin': 1829,
#  'ff': 1799,
#  'Version': 1798,
#  'ge': 1797,
#  'Qu': 1788,
#  'oc': 1781,
#  'If': 1778,
#  'th': 1776,
#  'arch': 1768,
#  'Config': 1766,
#  'pes': 1761,
#  'Reg': 1747,
#  'Local': 1745,
#  'pt': 1742,
#  'Group': 1740,
#  'ender': 1720,
#  'ations': 1715,
#  'Task': 1696,
#  'ader': 1690,
#  'use': 1685,
#  'ified': 1670,
#  'Te': 1668,
#  'Po': 1661,
#  'Al': 1660,
#  'ument': 1645,
#  'Oper': 1629,
#  'int': 1618,
#  'value': 1612,
#  'He': 1610,
#  'ew': 1608,
#  'fix': 1608,
#  'Stat': 1604,
#  'Session': 1600,
#  'ool': 1599,
#  'ert': 1594,
#  'ify': 1594,
#  'Info': 1592,
#  'ptor': 1582,
#  'Collection': 1573,
#  'Model': 1570,
#  'ance': 1568,
#  'od': 1568,
#  'ct': 1564,
#  'Ref': 1560,
#  'Gener': 1560,
#  'q': 1549,
#  'Configuration': 1549,
#  'Output': 1546,
#  'Handler': 1540,
#  'ext': 1535,
#  'te': 1521,
#  'ner': 1519,
#  'cri': 1514,
#  'aint': 1512,
#  'Manager': 1508,
#  'ose': 1505,
#  'ree': 1489,
#  'ue': 1488,
#  'ues': 1483,
#  'col': 1481,
#  'si': 1480,
#  'Return': 1476,
#  'Resource': 1465,
#  'ved': 1460,
#  'iv': 1443,
#  'one': 1440,
#  'lection': 1433,
#  'App': 1431,
#  'Mo': 1426,
#  'ifier': 1426,
#  'iz': 1419,
#  'Access': 1418,
#  'cal': 1406,
#  'Com': 1405,
#  'Str': 1404,
#  'imple': 1401,
#  'j': 1398,
#  'ay': 1397,
#  'View': 1382,
#  'ect': 1374,
#  'Bu': 1371,
#  'ml': 1369,
#  'Service': 1369,
#  'ev': 1363,
#  'iter': 1360,
#  'ave': 1353,
#  'itor': 1353,
#  'tribut': 1346,
#  'gener': 1344,
#  'Comm': 1343,
#  'mpl': 1339,
#  'ach': 1338,
#  'ess': 1329,
#  'ax': 1320,
#  'chem': 1299,
#  'li': 1298,
#  'unction': 1296,
#  'Ar': 1295,
#  'rent': 1293,
#  'ish': 1284,
#  'with': 1279,
#  'age': 1276,
#  'Base': 1271,
#  'ction': 1269,
#  'Man': 1256,
#  'und': 1242,
#  'cur': 1242,
#  'ages': 1239,
#  'back': 1233,
#  'ound': 1230,
#  'ser': 1228,
#  'config': 1226,
#  'Act': 1224,
#  'User': 1223,
#  'struct': 1218,
#  'ile': 1212,
#  'min': 1208,
#  'should': 1198,
#  'ID': 1187,
#  'ell': 1183,
#  'ode': 1182,
#  'Connection': 1180,
#  'ension': 1176,
#  'br': 1173,
#  'Builder': 1170,
#  'ass': 1162,
#  'Loc': 1161,
#  'row': 1154,
#  'Item': 1153,
#  'roll': 1135,
#  'Fr': 1133,
#  'val': 1128,
#  'Event': 1123,
#  'Document': 1118,
#  'umber': 1113,
#  'Sy': 1107,
#  'Log': 1102,
#  'low': 1088,
#  'put': 1085,
#  'Tr': 1083,
#  'our': 1083,
#  'Int': 1082,
#  'Stream': 1082,
#  'ence': 1077,
#  'K': 1074,
#  'Co': 1072,
#  'ong': 1068,
#  'Doc': 1063,
#  'Input': 1063,
#  'Ass': 1057,
#  'ep': 1054,
#  'ific': 1045,
#  'fi': 1045,
#  'rst': 1040,
#  'ite': 1039,
#  'match': 1020,
#  'gr': 1016,
#  'amp': 1015,
#  'pace': 1003,
#  'mo': 991,
#  'uc': 989,
#  'Cl': 986,
#  'Q': 984,
#  'sup': 984,
#  'ant': 982,
#  'Response': 970,
#  'str': 965,
#  'eta': 958,
#  'Over': 957,
#  'contain': 956,
#  'from': 953,
#  'Op': 943,
#  'append': 940,
#  'ava': 939,
#  'Date': 933,
#  'ill': 933,
#  'Command': 924,
#  'gin': 924,
#  'Token': 922,
#  'point': 919,
#  'aw': 917,
#  'pect': 917,
#  'Status': 912,
#  'copy': 908,
#  'ens': 907,
#  'ud': 906,
#  'Copy': 894,
#  'Provider': 883,
#  'older': 855,
#  'Package': 852,
#  'Ed': 830,
#  'ual': 824,
#  'pec': 821,
#  'Entry': 817,
#  'mar': 801,
#  'Out': 795,
#  'Ad': 792,
#  'trans': 786,
#  'ates': 783,
#  'ugin': 781,
#  'lean': 767,
#  'ma': 763,
#  'Hash': 753,
#  'og': 750,
#  'ub': 747,
#  'used': 746,
#  'Color': 736,
#  'Format': 736,
#  'next': 733,
#  'Impl': 732,
#  'uble': 728,
#  'file': 726,
#  'type': 722,
#  'ress': 717,
#  'Ac': 716,
#  'cre': 712,
#  'ber': 704,
#  'ateg': 702,
#  'nc': 701,
#  'print': 689,
#  'imit': 686,
#  'ata': 685,
#  'ry': 682,
#  'face': 677,
#  'ength': 676,
#  'Client': 672,
#  'code': 648,
#  'inter': 646,
#  'Iter': 645,
#  'word': 643,
#  'rid': 635,
#  'class': 625,
#  'posit': 623,
#  'ull': 617,
#  'ilter': 612,
#  'eter': 605,
#  'Col': 599,
#  'oolean': 598,
#  'uage': 596,
#  'path': 595,
#  'pr': 594,
#  'System': 587,
#  'Gr': 584,
#  'Ht': 582,
#  'log': 581,
#  'list': 581,
#  'ning': 580,
#  'ref': 580,
#  'ms': 570,
#  'index': 563,
#  'old': 563,
#  'cond': 562,
#  'order': 558,
#  'version': 557,
#  'reak': 557,
#  'Wor': 555,
#  'ty': 554,
#  'Layout': 553,
#  'ord': 541,
#  'untime': 540,
#  'map': 537,
#  'comm': 533,
#  'leg': 532,
#  'sub': 528,
#  'line': 528,
#  'Z': 527,
#  'size': 518,
#  'ire': 516,
#  'Ap': 498,
#  'ature': 498,
#  'The': 487,
#  'key': 484,
#  'bo': 483,
#  'sy': 479,
#  'name': 476,
#  'io': 474,
#  'uth': 471,
#  'Equals': 465,
#  'ker': 465,
#  'lement': 460,
#  'Label': 457,
#  'Button': 456,
#  'of': 454,
#  'Constan': 452,
#  'uct': 452,
#  'escri': 450,
#  'Buffer': 449,
#  'ak': 446,
#  'fa': 446,
#  'vate': 441,
#  'ifi': 441,
#  'field': 434,
#  'quired': 432,
#  'open': 429,
#  'ger': 428,
#  'sp': 415,
#  'yle': 414,
#  'stan': 411,
#  'move': 411,
#  'node': 409,
#  'Override': 405,
#  'we': 401,
#  'bug': 399,
#  'no': 397,
#  'ret': 396,
#  'cord': 384,
#  'so': 381,
#  'Page': 378,
#  'query': 377,
#  'als': 376,
#  'current': 373,
#  'request': 370,
#  'loat': 370,
#  'ts': 368,
#  'com': 368,
#  'pos': 367,
#  'Ab': 366,
#  'string': 365,
#  'nel': 358,
#  'andl': 350,
#  'arg': 345,
#  'link': 342,
#  'text': 341,
#  'ends': 340,
#  'Found': 336,
#  'mod': 334,
#  'ference': 331,
#  'Y': 330,
#  'oft': 330,
#  'tri': 329,
#  'tp': 326,
#  'may': 325,
#  'ash': 323,
#  'doc': 318,
#  'content': 317,
#  'try': 316,
#  'ere': 316,
#  'ected': 310,
#  'This': 309,
#  'ther': 309,
#  'ould': 309,
#  'state': 305,
#  'count': 300,
#  'null': 298,
#  'my': 297,
#  'property': 296,
#  'stem': 289,
#  'vid': 289,
#  'error': 281,
#  'message': 281,
#  'Assert': 280,
#  'ob': 278,
#  'ask': 277,
#  'aph': 272,
#  'work': 270,
#  'ans': 264,
#  'default': 259,
#  'ec': 258,
#  'URL': 253,
#  'Abstract': 251,
#  'Integer': 247,
#  'eth': 247,
#  'rit': 243,
#  'over': 237,
#  'ken': 232,
#  'he': 229,
#  'time': 222,
#  'context': 220,
#  'ession': 218,
#  'core': 216,
#  'etail': 215,
#  'll': 214,
#  'vice': 213,
#  'quire': 213,
#  'ient': 209,
#  'apt': 209,
#  'less': 208,
#  'Image': 208,
#  'char': 208,
#  'ST': 208,
#  'ns': 204,
#  'by': 203,
#  'stat': 200,
#  'ware': 199,
#  'param': 198,
#  'di': 196,
#  'item': 195,
#  'Public': 195,
#  'apter': 194,
#  'Im': 189,
#  'source': 189,
#  'parent': 187,
#  'element': 186,
#  'It': 186,
#  'mission': 186,
#  'True': 184,
#  'gle': 184,
#  'import': 182,
#  'max': 182,
#  'view': 176,
#  'lied': 168,
#  'sw': 166,
#  'internal': 164,
#  'ice': 164,
#  'alse': 160,
#  'last': 155,
#  'UR': 154,
#  'option': 152,
#  'onent': 151,
#  'istribut': 151,
#  'Ent': 148,
#  'fo': 147,
#  'imp': 145,
#  'other': 145,
#  'length': 144,
#  'umn': 142,
#  'ML': 139,
#  'legal': 136,
#  'vent': 135,
#  'group': 131,
#  'ho': 129,
#  'tribute': 129,
#  'begin': 128,
#  'pri': 128,
#  'press': 121,
#  'ayout': 121,
#  'data': 120,
#  'ype': 120,
#  'ror': 119,
#  'AP': 118,
#  'AS': 118,
#  'gram': 118,
#  'ray': 113,
#  'DE': 108,
#  'pression': 108,
#  'wh': 108,
#  'uration': 107,
#  'return': 105,
#  'But': 104,
#  'base': 103,
#  'server': 103,
#  'ON': 102,
#  'ln': 101,
#  'eld': 100,
#  'object': 98,
#  'long': 98,
#  'ime': 97,
#  'xt': 95,
#  'spec': 95,
#  'pon': 95,
#  'throw': 94,
#  'IO': 94,
#  'Inte': 91,
#  'ffer': 90,
#  'ilder': 90,
#  'ou': 88,
#  'input': 87,
#  'rc': 84,
#  'ith': 83,
#  'Er': 82,
#  'UT': 78,
#  'exception': 78,
#  'writ': 78,
#  'client': 78,
#  'static': 75,
#  'sion': 75,
#  'ath': 74,
#  'Constants': 74,
#  'unt': 74,
#  'event': 72,
#  'AT': 72,
#  'eature': 71,
#  'double': 69,
#  'ponse': 69,
#  'http': 69,
#  'service': 69,
#  'ager': 67,
#  'under': 64,
#  'til': 64,
#  'ource': 63,
#  'ride': 62,
#  'any': 61,
#  'Util': 60,
#  'IN': 59,
#  'model': 56,
#  'ich': 56,
#  'boolean': 55,
#  'user': 55,
#  'mis': 55,
#  'ream': 54,
#  'cont': 53,
#  'OF': 52,
#  'General': 51,
#  'andler': 51,
#  'ght': 50,
#  'pu': 49,
#  'lin': 49,
#  'target': 49,
#  'nection': 48,
#  'urn': 48,
#  'have': 48,
#  'OR': 48,
#  'break': 48,
#  'uld': 47,
#  'See': 47,
#  'case': 46,
#  'java': 45,
#  'IS': 44,
#  'instance': 44,
#  'see': 42,
#  'ui': 42,
#  'byte': 41,
#  'LE': 40,
#  'DO': 40,
#  'xml': 40,
#  'result': 40,
#  'auth': 39,
#  'actory': 38,
#  'applic': 38,
#  'NS': 38,
#  'unit': 37,
#  'fr': 36,
#  'CO': 36,
#  'gen': 35,
#  'AN': 35,
#  'ception': 35,
#  'required': 34,
#  'more': 34,
#  'super': 34,
#  'ener': 33,
#  'editor': 33,
#  'final': 33,
#  'SE': 33,
#  'clipse': 31,
#  'py': 30,
#  'odel': 30,
#  'RO': 30,
#  'PE': 29,
#  'will': 29,
#  'CH': 29,
#  'author': 29,
#  'ht': 28,
#  'AR': 28,
#  'the': 27,
#  'limit': 26,
#  'TH': 25,
#  'package': 25,
#  'net': 25,
#  'ED': 24,
#  'right': 24,
#  'mat': 24,
#  'implement': 23,
#  'perties': 23,
#  'rule': 21,
#  'abel': 21,
#  'AM': 21,
#  'terms': 21,
#  'LA': 19,
#  'LO': 19,
#  'generated': 19,
#  'ense': 19,
#  'CE': 19,
#  'Copyright': 18,
#  'protected': 17,
#  'License': 17,
#  'IL': 17,
#  'ng': 17,
#  'void': 17,
#  'IT': 16,
#  'ES': 16,
#  'stract': 16,
#  'vider': 16,
#  'pert': 15,
#  'AB': 15,
#  'ER': 15,
#  'true': 15,
#  'RE': 15,
#  'PO': 14,
#  'TY': 14,
#  'frame': 14,
#  'dex': 14,
#  'this': 14,
#  'UN': 12,
#  'AL': 12,
#  'distribut': 12,
#  'clip': 12,
#  'TO': 11,
#  'eng': 11,
#  'but': 11,
#  'false': 11,
#  'Utils': 11,
#  'TI': 10,
#  'Cli': 10,
#  'throws': 10,
#  'ey': 10,
#  'EN': 9,
#  'ton': 9,
#  'ery': 9,
#  'specific': 9,
#  'NO': 9,
#  'public': 9,
#  'LI': 8,
#  'language': 8,
#  'roid': 8,
#  'distributed': 8,
#  'EX': 7,
#  'private': 6,
#  'extends': 6,
#  'wid': 6,
#  'that': 5,
#  'quest': 5,
#  'Vers': 4,
#  'wor': 4,
#  'MP': 4,
#  'src': 4,
#  'api': 4,
#  'NU': 4,
#  'che': 4,
#  'CON': 4,
#  'lang': 4,
#  'WAR': 4,
#  'prot': 3,
#  'ither': 3,
#  'ING': 3,
#  'www': 3,
#  '_': 3,
#  'org': 3,
#  'istri': 3,
#  'eclipse': 3,
#  'Lic': 3,
#  'CT': 3,
#  'Apache': 3,
#  'ethod': 2,
#  'AME': 2,
#  'NON': 2,
#  'AG': 2,
#  'UL': 2,
#  'Software': 2,
#  'catch': 2,
#  'You': 2,
#  'util': 2,
#  'TION': 2,
#  'either': 2,
#  '$': 1,
#  '2': 1,
#  'HO': 1,
#  'implied': 1,
#  'fault': 1,
#  'else': 1,
#  'instanceof': 1,
#  'FOR': 1,
#  ...}

# %%
def plotWord(word, target_to_count):
    sorted_doc = (sorted(target_to_count.items(), key=operator.itemgetter(1)))[::-1]
    just_the_occur = []
    just_the_rank = []
    word_rank = 0
    word_frequency = 0

    entry_num = 1
    for entry in sorted_doc:
        if (entry[0] == word):
            word_rank = entry_num
            word_frequency = entry[1]

        just_the_rank.append(entry_num)
        entry_num += 1
        just_the_occur.append(entry[1])
    
    plt.title("Word Frequencies")
    plt.ylabel("Total Number of Occurrences")
    plt.xlabel("Rank of word(\"" + word + "\" is rank " + str(word_rank) + ")")
    plt.loglog(just_the_rank, just_the_occur, basex=10)
    plt.scatter(
        [word_rank],
        [word_frequency],
        color="orange",
        marker="*",
        s=100,
        label=word
    )
    plt.show()

# %%
plotWord("return", target_to_count)
plotWord("get", target_to_count)
